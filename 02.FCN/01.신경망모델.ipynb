# %% [markdown]
# ## 신경망 모델
# - 이진 분류: 유방암 예측 사례

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - 데이터 준비

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
cancer = load_breast_cancer()
cancer.data.shape
# Out:
# (569, 30)

# %%
cancer_std = StandardScaler().fit_transform(cancer.data)

# %% [markdown]
# #### 1. 데이터를 정규/표준화 하지 않은 경우

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, test_size=0.2, random_state=2023
)

# %% [markdown]
# - 모델 정의

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense       # Fully Connected Network

# %%
model = Sequential([
    Dense(100, input_dim=30, activation='relu'),    # 동시에 몇개의 입력을 받을것이냐
    Dense(24, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               3100
#
#  dense_4 (Dense)             (None, 24)                2424
#
#  dense_5 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 5549 (21.68 KB)
# Trainable params: 5549 (21.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - 모델 설정(컴파일)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 모델 학습

# %%
history = model.fit(X_train, y_train,
                    validation_split=0.2,       # 학습중 검증용
                    epochs = 100,               # 반복 횟수
                    batch_size=100)             # 동시에 몇개의 데이터를 메모리에 로드하는가         # 동시에 몇개의 데이터를 메모리에 로드하는가
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 69ms/step - loss: 79.1289 - accuracy: 0.3599 - val_loss: 48.8600 - val_accuracy: 0.4286
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 36.4956 - accuracy: 0.3599 - val_loss: 9.1192 - val_accuracy: 0.4286
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 6.6575 - accuracy: 0.6676 - val_loss: 26.0049 - val_accuracy: 0.5714
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 20.3596 - accuracy: 0.6401 - val_loss: 15.4218 - val_accuracy: 0.5824
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 5.7152 - accuracy: 0.7335 - val_loss: 3.6292 - val_accuracy: 0.4835
# Epoch 6/100
# 4/4 [==============================] - 0s 11ms/step - loss: 6.3244 - accuracy: 0.3764 - val_loss: 7.4240 - val_accuracy: 0.4286
# Epoch 7/100
# 4/4 [==============================] - 0s 12ms/step - loss: 4.5218 - accuracy: 0.4670 - val_loss: 0.2740 - val_accuracy: 0.9341
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.4610 - accuracy: 0.8571 - val_loss: 3.5537 - val_accuracy: 0.6923
# Epoch 9/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.8757 - accuracy: 0.7940 - val_loss: 0.4471 - val_accuracy: 0.9231
# Epoch 10/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4676 - accuracy: 0.9148 - val_loss: 1.6068 - val_accuracy: 0.6813
# Epoch 11/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2524 - accuracy: 0.7418 - val_loss: 0.9188 - val_accuracy: 0.7582
# Epoch 12/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5645 - accuracy: 0.8901 - val_loss: 0.3206 - val_accuracy: 0.9231
# Epoch 13/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7165 - accuracy: 0.8874 - val_loss: 0.3379 - val_accuracy: 0.9231
# Epoch 14/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6036 - accuracy: 0.9038 - val_loss: 0.4239 - val_accuracy: 0.8681
# Epoch 15/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4859 - accuracy: 0.8956 - val_loss: 0.5589 - val_accuracy: 0.8571
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4639 - accuracy: 0.8929 - val_loss: 0.3190 - val_accuracy: 0.8791
# Epoch 17/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4456 - accuracy: 0.9011 - val_loss: 0.2914 - val_accuracy: 0.9341
# Epoch 18/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4809 - accuracy: 0.9011 - val_loss: 0.3322 - val_accuracy: 0.8681
# Epoch 19/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4107 - accuracy: 0.9038 - val_loss: 0.3712 - val_accuracy: 0.8681
# Epoch 20/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4105 - accuracy: 0.8956 - val_loss: 0.3841 - val_accuracy: 0.8681
# Epoch 21/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4078 - accuracy: 0.8984 - val_loss: 0.3219 - val_accuracy: 0.8901
# Epoch 22/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.4144 - accuracy: 0.8984 - val_loss: 0.3815 - val_accuracy: 0.8681
# Epoch 23/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4245 - accuracy: 0.8956 - val_loss: 0.2924 - val_accuracy: 0.9231
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3791 - accuracy: 0.9011 - val_loss: 0.4493 - val_accuracy: 0.8681
# Epoch 25/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3910 - accuracy: 0.8956 - val_loss: 0.3425 - val_accuracy: 0.8681
# Epoch 26/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3694 - accuracy: 0.9066 - val_loss: 0.2862 - val_accuracy: 0.9341
# Epoch 27/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3702 - accuracy: 0.9093 - val_loss: 0.4005 - val_accuracy: 0.8791
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3759 - accuracy: 0.8956 - val_loss: 0.3575 - val_accuracy: 0.8681
# Epoch 29/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3424 - accuracy: 0.9066 - val_loss: 0.2984 - val_accuracy: 0.9011
# Epoch 30/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3461 - accuracy: 0.9093 - val_loss: 0.3205 - val_accuracy: 0.8901
# Epoch 31/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3384 - accuracy: 0.9121 - val_loss: 0.3319 - val_accuracy: 0.8791
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3323 - accuracy: 0.9093 - val_loss: 0.3071 - val_accuracy: 0.8901
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3362 - accuracy: 0.9011 - val_loss: 0.3248 - val_accuracy: 0.8791
# Epoch 34/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3224 - accuracy: 0.9093 - val_loss: 0.2902 - val_accuracy: 0.9011
# Epoch 35/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3319 - accuracy: 0.9093 - val_loss: 0.3077 - val_accuracy: 0.8901
# Epoch 36/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3399 - accuracy: 0.8984 - val_loss: 0.3516 - val_accuracy: 0.8681
# Epoch 37/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3083 - accuracy: 0.9011 - val_loss: 0.2652 - val_accuracy: 0.9121
# Epoch 38/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3280 - accuracy: 0.9066 - val_loss: 0.3304 - val_accuracy: 0.8791
# Epoch 39/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3382 - accuracy: 0.8874 - val_loss: 0.3604 - val_accuracy: 0.8681
# Epoch 40/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3184 - accuracy: 0.9038 - val_loss: 0.2593 - val_accuracy: 0.9231
# Epoch 41/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3135 - accuracy: 0.9148 - val_loss: 0.3759 - val_accuracy: 0.8791
# Epoch 42/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3290 - accuracy: 0.9011 - val_loss: 0.2659 - val_accuracy: 0.9011
# Epoch 43/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3339 - accuracy: 0.9038 - val_loss: 0.2597 - val_accuracy: 0.9011
# Epoch 44/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2900 - accuracy: 0.9038 - val_loss: 0.3670 - val_accuracy: 0.8791
# Epoch 45/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2941 - accuracy: 0.9066 - val_loss: 0.2560 - val_accuracy: 0.9011
# Epoch 46/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2955 - accuracy: 0.9038 - val_loss: 0.2691 - val_accuracy: 0.9011
# Epoch 47/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2795 - accuracy: 0.9148 - val_loss: 0.2762 - val_accuracy: 0.9011
# Epoch 48/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2737 - accuracy: 0.9093 - val_loss: 0.3072 - val_accuracy: 0.8791
# Epoch 49/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2885 - accuracy: 0.9121 - val_loss: 0.2585 - val_accuracy: 0.9011
# Epoch 50/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2663 - accuracy: 0.9093 - val_loss: 0.3053 - val_accuracy: 0.8791
# Epoch 51/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2864 - accuracy: 0.9066 - val_loss: 0.2587 - val_accuracy: 0.9011
# Epoch 52/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2646 - accuracy: 0.9066 - val_loss: 0.3066 - val_accuracy: 0.8791
# Epoch 53/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2659 - accuracy: 0.9011 - val_loss: 0.2342 - val_accuracy: 0.9231
# Epoch 54/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2844 - accuracy: 0.9066 - val_loss: 0.2876 - val_accuracy: 0.8791
# Epoch 55/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2618 - accuracy: 0.9066 - val_loss: 0.2681 - val_accuracy: 0.9011
# Epoch 56/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2538 - accuracy: 0.9093 - val_loss: 0.2386 - val_accuracy: 0.9011
# Epoch 57/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2826 - accuracy: 0.9121 - val_loss: 0.2717 - val_accuracy: 0.8791
# Epoch 58/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2505 - accuracy: 0.9121 - val_loss: 0.2493 - val_accuracy: 0.9011
# Epoch 59/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2492 - accuracy: 0.9121 - val_loss: 0.2316 - val_accuracy: 0.9011
# Epoch 60/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2492 - accuracy: 0.9148 - val_loss: 0.2453 - val_accuracy: 0.9011
# Epoch 61/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2605 - accuracy: 0.9038 - val_loss: 0.2268 - val_accuracy: 0.9121
# Epoch 62/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2614 - accuracy: 0.9121 - val_loss: 0.2288 - val_accuracy: 0.9011
# Epoch 63/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2622 - accuracy: 0.9093 - val_loss: 0.2397 - val_accuracy: 0.9011
# Epoch 64/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2266 - accuracy: 0.9148 - val_loss: 0.2117 - val_accuracy: 0.9341
# Epoch 65/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2544 - accuracy: 0.9066 - val_loss: 0.3620 - val_accuracy: 0.8462
# Epoch 66/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2803 - accuracy: 0.9093 - val_loss: 0.2105 - val_accuracy: 0.9231
# Epoch 67/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2726 - accuracy: 0.8929 - val_loss: 0.2080 - val_accuracy: 0.9231
# Epoch 68/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2746 - accuracy: 0.9011 - val_loss: 0.2284 - val_accuracy: 0.9011
# Epoch 69/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2984 - accuracy: 0.8764 - val_loss: 0.2034 - val_accuracy: 0.9341
# Epoch 70/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2805 - accuracy: 0.9066 - val_loss: 0.2650 - val_accuracy: 0.8791
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2427 - accuracy: 0.9066 - val_loss: 0.2006 - val_accuracy: 0.9341
# Epoch 72/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2333 - accuracy: 0.9176 - val_loss: 0.2718 - val_accuracy: 0.8901
# Epoch 73/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2319 - accuracy: 0.9203 - val_loss: 0.1990 - val_accuracy: 0.9231
# Epoch 74/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2152 - accuracy: 0.9148 - val_loss: 0.2620 - val_accuracy: 0.8901
# Epoch 75/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2204 - accuracy: 0.9148 - val_loss: 0.2000 - val_accuracy: 0.9231
# Epoch 76/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2216 - accuracy: 0.9121 - val_loss: 0.1990 - val_accuracy: 0.9231
# Epoch 77/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2164 - accuracy: 0.9203 - val_loss: 0.2060 - val_accuracy: 0.9121
# Epoch 78/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2062 - accuracy: 0.9203 - val_loss: 0.2053 - val_accuracy: 0.9121
# Epoch 79/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2054 - accuracy: 0.9176 - val_loss: 0.1925 - val_accuracy: 0.9231
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2317 - accuracy: 0.9176 - val_loss: 0.3423 - val_accuracy: 0.8462
# Epoch 81/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2568 - accuracy: 0.8956 - val_loss: 0.2150 - val_accuracy: 0.9231
# Epoch 82/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2999 - accuracy: 0.9011 - val_loss: 0.5250 - val_accuracy: 0.7582
# Epoch 83/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2736 - accuracy: 0.8846 - val_loss: 0.2923 - val_accuracy: 0.9231
# Epoch 84/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2997 - accuracy: 0.9066 - val_loss: 0.6184 - val_accuracy: 0.7363
# Epoch 85/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3314 - accuracy: 0.8709 - val_loss: 0.2173 - val_accuracy: 0.9231
# Epoch 86/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2524 - accuracy: 0.9121 - val_loss: 0.2131 - val_accuracy: 0.9011
# Epoch 87/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2192 - accuracy: 0.9286 - val_loss: 0.1827 - val_accuracy: 0.9231
# Epoch 88/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1958 - accuracy: 0.9286 - val_loss: 0.2345 - val_accuracy: 0.8901
# Epoch 89/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2171 - accuracy: 0.9176 - val_loss: 0.1933 - val_accuracy: 0.9231
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2407 - accuracy: 0.8819 - val_loss: 0.2251 - val_accuracy: 0.9231
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3034 - accuracy: 0.8874 - val_loss: 0.5652 - val_accuracy: 0.7473
# Epoch 92/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3436 - accuracy: 0.8626 - val_loss: 0.2038 - val_accuracy: 0.9231
# Epoch 93/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2331 - accuracy: 0.9066 - val_loss: 0.2109 - val_accuracy: 0.8901
# Epoch 94/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2300 - accuracy: 0.9148 - val_loss: 0.2093 - val_accuracy: 0.9011
# Epoch 95/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2171 - accuracy: 0.9148 - val_loss: 0.1773 - val_accuracy: 0.9231
# Epoch 96/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1905 - accuracy: 0.9203 - val_loss: 0.2726 - val_accuracy: 0.8791
# Epoch 97/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2254 - accuracy: 0.9203 - val_loss: 0.1746 - val_accuracy: 0.9341
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1948 - accuracy: 0.9286 - val_loss: 0.1869 - val_accuracy: 0.9231
# Epoch 99/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2131 - accuracy: 0.9231 - val_loss: 0.2065 - val_accuracy: 0.9011
# Epoch 100/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1839 - accuracy: 0.9313 - val_loss: 0.1715 - val_accuracy: 0.9341

# %% [markdown]
# - 모델평가

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2163 - accuracy: 0.9298
# [0.2163001000881195, 0.9298245906829834]

# %% [markdown]
# - 훈련과정 시각화
#     - epoch에 따른 accuracy, val_loss의 변화

# %%
y_acc = history.history['accuracy']
y_vloss = history.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1]), plt.xlabel('Epoch')
plt.title('No feature transformation')
plt.show()

# %% [markdown]
# #### 2. 데이터를 표준화한 경우

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(
    cancer_std,cancer.target, stratify=cancer.target, test_size=0.2, random_state=2023
)

# %%
model2 = Sequential()
model2.add(Dense(100, input_shape=(30,), activation='relu'))
model2.add(Dense(24, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 100)               3100
#
#  dense_8 (Dense)             (None, 24)                2424
#
#  dense_9 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 5549 (21.68 KB)
# Trainable params: 5549 (21.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 컴파일
model2.compile('adam', 'binary_crossentropy', metrics=['accuracy'])

# %%
# 모델 학습
history2 = model2.fit(X_train2, y_train2, validation_split=0.2,
                      epochs=100, batch_size=100, verbose=0)

# %%
# 모델 평가
model2.evaluate(X_test2, y_test2)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2555 - accuracy: 0.9561
# [0.2555364668369293, 0.9561403393745422]

# %%
# 학습과정 시각화
y_acc2 = history2.history['accuracy']
y_vloss2 = history2.history['val_loss']

plt.figure(figsize=(12,7))
plt.plot(xs, y_acc2, label='train accuracy')
plt.plot(xs, y_vloss2, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1.1]), plt.xlabel('Epoch')
plt.title('with feature transformation')
plt.show()
