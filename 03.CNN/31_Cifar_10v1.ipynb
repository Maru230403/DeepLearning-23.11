# %% [markdown]
# ## Cifar-10 이미지 분류 v1

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2023
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 탐색 및 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.figure(figsize=(8,2))
for i in range(10):
  plt.subplot(1,10,i+1)
  plt.imshow(X_train[i]), plt.xticks([]), plt.yticks([])
  plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: scaling
X_train = X_train / 255.
X_test = X_test / 255.

# %%
# y data: one hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras. models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1250858 (4.77 MB)
# Trainable params: 1250858 (4.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

model_path = 'best-cifar10-v1.h5'
mc = ModelCheckpoint(model_path, save_bestZ_only=True, verbose=1)
es = EarlyStopping(patience=5)

# %%
hist = model.fit(X_train, Y_train, validation_split=0.2,
                 epochs=100, batch_size=32, callbacks=[mc,es])
# Out:
# Epoch 1/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.5624 - accuracy: 0.4252
# Epoch 1: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 21s 6ms/step - loss: 1.5610 - accuracy: 0.4257 - val_loss: 1.2792 - val_accuracy: 0.5464
# Epoch 2/100
#   17/1250 [..............................] - ETA: 8s - loss: 1.2760 - accuracy: 0.5184
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1243/1250 [============================>.] - ETA: 0s - loss: 1.1975 - accuracy: 0.5725
# Epoch 2: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 1.1963 - accuracy: 0.5727 - val_loss: 1.0096 - val_accuracy: 0.6512
# Epoch 3/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.0303 - accuracy: 0.6354
# Epoch 3: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 1.0302 - accuracy: 0.6355 - val_loss: 0.9086 - val_accuracy: 0.6818
# Epoch 4/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9225 - accuracy: 0.6771
# Epoch 4: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.9224 - accuracy: 0.6771 - val_loss: 0.8742 - val_accuracy: 0.6925
# Epoch 5/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.8507 - accuracy: 0.6999
# Epoch 5: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.8509 - accuracy: 0.6999 - val_loss: 0.7645 - val_accuracy: 0.7324
# Epoch 6/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.8039 - accuracy: 0.7181
# Epoch 6: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8039 - accuracy: 0.7181 - val_loss: 0.7716 - val_accuracy: 0.7333
# Epoch 7/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.7492 - accuracy: 0.7375
# Epoch 7: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7488 - accuracy: 0.7378 - val_loss: 0.7177 - val_accuracy: 0.7525
# Epoch 8/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7177 - accuracy: 0.7479
# Epoch 8: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.7175 - accuracy: 0.7480 - val_loss: 0.6972 - val_accuracy: 0.7631
# Epoch 9/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6825 - accuracy: 0.7603
# Epoch 9: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.6825 - accuracy: 0.7603 - val_loss: 0.6814 - val_accuracy: 0.7586
# Epoch 10/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6545 - accuracy: 0.7703
# Epoch 10: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6545 - accuracy: 0.7702 - val_loss: 0.6778 - val_accuracy: 0.7680
# Epoch 11/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6221 - accuracy: 0.7799
# Epoch 11: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6220 - accuracy: 0.7800 - val_loss: 0.7409 - val_accuracy: 0.7472
# Epoch 12/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6095 - accuracy: 0.7843
# Epoch 12: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6094 - accuracy: 0.7845 - val_loss: 0.6646 - val_accuracy: 0.7726
# Epoch 13/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.5910 - accuracy: 0.7897
# Epoch 13: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5908 - accuracy: 0.7898 - val_loss: 0.6708 - val_accuracy: 0.7698
# Epoch 14/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5695 - accuracy: 0.7993
# Epoch 14: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5695 - accuracy: 0.7993 - val_loss: 0.6790 - val_accuracy: 0.7716
# Epoch 15/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.5603 - accuracy: 0.8029
# Epoch 15: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5600 - accuracy: 0.8029 - val_loss: 0.6908 - val_accuracy: 0.7708
# Epoch 16/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.8118
# Epoch 16: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5354 - accuracy: 0.8118 - val_loss: 0.6670 - val_accuracy: 0.7744
# Epoch 17/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.5254 - accuracy: 0.8148
# Epoch 17: saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5250 - accuracy: 0.8149 - val_loss: 0.6953 - val_accuracy: 0.7713

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.7028 - accuracy: 0.7692
# [0.7027988433837891, 0.7692000269889832]

# %% [markdown]
# - 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.xlabel('epoch')
plt.title('Cifar-10 CNN Model v1')
plt.show()
